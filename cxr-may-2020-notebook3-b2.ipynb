# %% [markdown]
# ### For preparing Udacity exam 1.
# changes according wp from NPJ
#
# Notebook 2 is the Notebook supporting K-fold CV

# %%
# eventually install EfficientNets
# or other needed packages
# !pip install -q efficientnet >> /dev/null
# Out:
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# this Notebook is the second to work on my CXR TFREC Dataset
# the dataset contains, in TFREC format, all images taken from NIH CXR dataset
# image have been transformed from initial format (png, 1024x1024)
# to JPEG 256x256 and packed in TFREC files

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from kaggle_datasets import KaggleDatasets
import tensorflow as tf
import tensorflow.keras.backend as K
import efficientnet.tfkeras as efn

from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import os
import re, math
import time

# %%
# to remove some warnings

# TF2 way to reduce logging
# this remove also INFO, verify if needed
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
DEVICE = "TPU" # or "TPU"

# TFRecords file for training/validation
GCS_PATH = KaggleDatasets().get_gcs_path('cxr-tfrec256-may2020')

IMG_SIZES = 256

IMAGE_SIZE = [IMG_SIZES, IMG_SIZES]

# tune it, dependes on Image, size, TPU or GPU
#BATCH_SIZE = 64
BATCH_SIZE = 32

EPOCHS = 50

# for K-fold CV
FOLDS = 5

# WHICH EFFICIENTNET TO USE (B?, B0 from B7)
EFF_NETS = 2

# %%
if DEVICE == "TPU":
    print("connecting to TPU...")
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        print("Could not connect to TPU")
        tpu = None

    if tpu:
        try:
            print("initializing  TPU ...")
            tf.config.experimental_connect_to_cluster(tpu)
            tf.tpu.experimental.initialize_tpu_system(tpu)
            strategy = tf.distribute.experimental.TPUStrategy(tpu)
            print("TPU initialized")
        except _:
            print("failed to initialize TPU")
    else:
        DEVICE = "GPU"

if DEVICE == "GPU":
    n_gpu = len(tf.config.experimental.list_physical_devices('GPU'))
    print("Num GPUs Available: ", n_gpu)
    
    if n_gpu > 1:
        print("Using strategy for multiple GPU")
        strategy = tf.distribute.MirroredStrategy()
    else:
        print('Standard strategy for GPU...')
        strategy = tf.distribute.get_strategy()

AUTO     = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync

print(f'REPLICAS: {REPLICAS}')
# Out:
# connecting to TPU...
# Running on TPU  grpc://10.0.0.2:8470
# initializing  TPU ...
# TPU initialized
# REPLICAS: 8

# %%
# changed
ROT_ = 20.0
SHR_ = 2.0
# changed
HZOOM_ = 4.0
WZOOM_ = 4.0
# changed
HSHIFT_ = 4.0
WSHIFT_ = 4.0

# image augmentation
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear    = math.pi * shear    / 180.

    def get_3x3_mat(lst):
        return tf.reshape(tf.concat([lst],axis=0), [3,3])
    
    # ROTATION MATRIX
    c1   = tf.math.cos(rotation)
    s1   = tf.math.sin(rotation)
    one  = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    
    rotation_matrix = get_3x3_mat([c1,   s1,   zero, 
                                   -s1,  c1,   zero, 
                                   zero, zero, one])    
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)    
    
    shear_matrix = get_3x3_mat([one,  s2,   zero, 
                                zero, c2,   zero, 
                                zero, zero, one])        
    # ZOOM MATRIX
    zoom_matrix = get_3x3_mat([one/height_zoom, zero,           zero, 
                               zero,            one/width_zoom, zero, 
                               zero,            zero,           one])    
    # SHIFT MATRIX
    shift_matrix = get_3x3_mat([one,  zero, height_shift, 
                                zero, one,  width_shift, 
                                zero, zero, one])
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), 
                 K.dot(zoom_matrix,     shift_matrix))

def transform(image, DIM=256):    
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    XDIM = DIM%2 #fix for size 331
    
    rot = ROT_ * tf.random.normal([1], dtype='float32')
    shr = SHR_ * tf.random.normal([1], dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1], dtype='float32') / HZOOM_
    w_zoom = 1.0 + tf.random.normal([1], dtype='float32') / WZOOM_
    h_shift = HSHIFT_ * tf.random.normal([1], dtype='float32') 
    w_shift = WSHIFT_ * tf.random.normal([1], dtype='float32') 

    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x   = tf.repeat(tf.range(DIM//2, -DIM//2,-1), DIM)
    y   = tf.tile(tf.range(-DIM//2, DIM//2), [DIM])
    z   = tf.ones([DIM*DIM], dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m, tf.cast(idx, dtype='float32'))
    idx2 = K.cast(idx2, dtype='int32')
    idx2 = K.clip(idx2, -DIM//2+XDIM+1, DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack([DIM//2-idx2[0,], DIM//2-1+idx2[1,]])
    d    = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM,3])

# %%
# not using metadata (only image, for now)
def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "image_idx": tf.io.FixedLenFeature([], tf.string),
        'label' : tf.io.FixedLenFeature([], tf.int64)
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    
    # do image augmentation
    image = transform(image, DIM=IMG_SIZES)
    # hearth on the right is not labeled as anomaly, therefore it is ok to flip
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_saturation(image, 0.7, 1.3)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.image.random_brightness(image, 0.1)
        
    image_idx = example['image_idx']
    label = example['label']
        
    return image, label 

def read_labeled_tfrecord_for_test(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "image_idx": tf.io.FixedLenFeature([], tf.string),
        'label' : tf.io.FixedLenFeature([], tf.int64)
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    
    # DON't do image augmentation
    label = example['label']
        
    return image, label 

def read_unlabeled_tfrecord(example, return_image_name):
    tfrec_format = {
        'image'                        : tf.io.FixedLenFeature([], tf.string),
        'image_idx'                   : tf.io.FixedLenFeature([], tf.string),
    }
    example = tf.io.parse_single_example(example, tfrec_format)
    return example['image'], example['image_idx'] if return_image_name else 0

def decode_image(image_data):
    # qua dovrebbe fare la conversione in RGB come richiesto da EfficientNet
    image = tf.image.decode_jpeg(image_data, channels=3)
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

# count # of images in files.. (embedded in file name)
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) 
         for filename in filenames]
    return np.sum(n)

# %%
def load_dataset(filenames, labeled=True, ordered=False, isTest=False):
    # Read from TFRecords. For optimal performance, reading from multiple files at once and
    # disregarding data order. Order does not matter since we will be shuffling the data anyway.

    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    
    if isTest == False:
        dataset = dataset.map(read_labeled_tfrecord)
    else:
        dataset = dataset.map(read_labeled_tfrecord_for_test)
    
    # returns a dataset of (image, labels) pairs if labeled=True or (image, id) pairs if labeled=False
    return dataset

def get_training_dataset(filenames):
    dataset = load_dataset(filenames, labeled=True, isTest = False)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_valid_dataset(filenames):
    dataset = load_dataset(filenames, labeled=True, isTest = True)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_test_dataset(filenames):
    # for predictions it is crucial the ordering
    dataset = load_dataset(filenames, labeled=True, isTest = True, ordered=True)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

# %%
# here we define the DNN Model

EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7]

# as default it used B0

def build_model(dim = IMG_SIZES, ef = 0):
    inp = tf.keras.layers.Input(shape=(*IMAGE_SIZE, 3))
    
    base = EFNS[ef](input_shape=(*IMAGE_SIZE, 3), weights='imagenet', include_top = False)
    
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs = inp,outputs = x)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.001)
    
    # removed label smoothing
    fn_loss = tf.keras.losses.BinaryCrossentropy() 
    
    # loss = [focal_loss]
    model.compile(optimizer = opt, loss = [fn_loss], metrics=['AUC', 'accuracy'])
    
    return model

# %%
try_model = build_model(dim=IMG_SIZES, ef=EFF_NETS)

try_model.summary()
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b2_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 31940608/31936256 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# efficientnet-b2 (Model)      (None, 8, 8, 1408)        7768562
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1409
# =================================================================
# Total params: 7,769,971
# Trainable params: 7,702,403
# Non-trainable params: 67,568
# _________________________________________________________________

# %%
# definisce la variazione temporale del learning rate

def get_lr_callback(batch_size=8):
    lr_start   = 0.00001
    lr_max     = 0.000015 * 10
    # lr_max     = 0.00001 * 20
    lr_min     = 0.00001
    lr_ramp_ep = 20
    # lr_ramp_ep = 20
    lr_sus_ep  = 10
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)
    
    return lr_callback

# %%
class LRFinder(tf.keras.callbacks.Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186

    '''
    
    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=None, epochs=None):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
 
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        plt.grid()
        plt.show()
        
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        plt.grid()
        plt.show()

# %%
all_files = tf.io.gfile.glob(GCS_PATH + '/train_valid*.tfrec')
num_total_files = len(all_files)

n_images = count_data_items(all_files)

print('Total number of image for train-validation:', n_images)
# Out:
# Total number of image for train-validation: 10280

# %%
def train_one_fold(fold, files_train, files_valid):
    # train_files = list of train_files names
    # valid_files = list of valid files
    
    # constant to customize output
    VERBOSE = 1
    tStart = time.time()
    
    # BUILD MODEL
    if DEVICE=='TPU':
        # to avoid OOM
        tf.tpu.experimental.initialize_tpu_system(tpu)
    
    K.clear_session()
    with strategy.scope():
        print('Building model...')
        model = build_model(dim=IMG_SIZES, ef=EFF_NETS)
    
    # callback to save best model for each fold
    sv = tf.keras.callbacks.ModelCheckpoint('fold-%i.h5'%fold, monitor='val_loss', verbose=1, save_best_only=True,
                                            save_weights_only=True, mode='min', save_freq='epoch')
    
    # TRAIN
    history = model.fit(get_training_dataset(files_train), 
                        epochs=EPOCHS, 
                        callbacks = [sv, get_lr_callback(BATCH_SIZE)], 
                        steps_per_epoch = count_data_items(files_train)/BATCH_SIZE//REPLICAS,
                        validation_data = get_valid_dataset(files_valid), 
                        validation_steps = count_data_items(files_valid)/BATCH_SIZE//REPLICAS,
                        verbose=VERBOSE)
    
    tElapsed = round(time.time() - tStart, 1)
    
    print(' ')
    print('Time (sec) elapsed: ', tElapsed)
    print('...')
    print('...')
    
    return history

# %%
# code to manage K-fold CV
SHOW_FILES = True

skf = KFold(n_splits = FOLDS, shuffle = True, random_state=42)

oof_pred = []; oof_tar = []; oof_val = []; oof_names = [] 
# preds = np.zeros((count_data_items(files_test),1))

# for others investigations
# we store all the history
histories = []

for fold,(idxT,idxV) in enumerate(skf.split(np.arange(num_total_files))):
    # display fold info
    print('')
    print('#'*60) 
    print('#### FOLD', fold+1)
    
    print('#### Image Size %i, EfficientNet B%i, batch_size %i'%
          (IMG_SIZES, EFF_NETS, BATCH_SIZE*REPLICAS))
    print('#### Epochs: %i' %(EPOCHS))
    print('#'*60)
    
    # CREATE TRAIN AND VALIDATION SUBSETS
    train_files = tf.io.gfile.glob([GCS_PATH + '/train_valid%.2i*.tfrec'%x for x in idxT])
    valid_files = tf.io.gfile.glob([GCS_PATH + '/train_valid%.2i*.tfrec'%x for x in idxV])
    
    if SHOW_FILES:
        print('Number of training images', count_data_items(train_files))
        print('Number of validation images', count_data_items(valid_files))
    
    # in files h5 fol are numbered starting from 1
    
    # here launch the training for the fold
    history = train_one_fold(fold+1, train_files, valid_files)
    
    histories.append(history)
# Out:
# ############################################################
# #### FOLD 1
# #### Image Size 256, EfficientNet B2, batch_size 256
# #### Epochs: 50
# ############################################################
# Number of training images 7280
# Number of validation images 3000
# Building model...
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.5759 - auc: 0.6103 - loss: 0.6777
# Epoch 00001: val_loss improved from inf to 0.66311, saving model to fold-1.h5
# 28/28 [==============================] - 18s 642ms/step - accuracy: 0.5759 - auc: 0.6103 - loss: 0.6777 - val_accuracy: 0.6278 - val_auc: 0.6922 - val_loss: 0.6631 - lr: 1.0000e-05
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 1.7e-05.
# Epoch 2/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.6395 - auc: 0.7006 - loss: 0.6518
# Epoch 00002: val_loss improved from 0.66311 to 0.65518, saving model to fold-1.h5
# 28/28 [==============================] - 5s 188ms/step - accuracy: 0.6395 - auc: 0.7006 - loss: 0.6518 - val_accuracy: 0.6307 - val_auc: 0.7450 - val_loss: 0.6552 - lr: 1.7000e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 2.4e-05.
# Epoch 3/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7065 - auc: 0.7624 - loss: 0.6142
# Epoch 00003: val_loss improved from 0.65518 to 0.63866, saving model to fold-1.h5
# 28/28 [==============================] - 5s 181ms/step - accuracy: 0.7065 - auc: 0.7624 - loss: 0.6142 - val_accuracy: 0.6477 - val_auc: 0.7929 - val_loss: 0.6387 - lr: 2.4000e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 3.1e-05.
# Epoch 4/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7009 - auc: 0.7650 - loss: 0.5930
# Epoch 00004: val_loss improved from 0.63866 to 0.61726, saving model to fold-1.h5
# 28/28 [==============================] - 5s 188ms/step - accuracy: 0.7009 - auc: 0.7650 - loss: 0.5930 - val_accuracy: 0.6619 - val_auc: 0.8367 - val_loss: 0.6173 - lr: 3.1000e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 3.8e-05.
# Epoch 5/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7411 - auc: 0.8136 - loss: 0.5447
# Epoch 00005: val_loss improved from 0.61726 to 0.59145, saving model to fold-1.h5
# 28/28 [==============================] - 5s 188ms/step - accuracy: 0.7411 - auc: 0.8136 - loss: 0.5447 - val_accuracy: 0.6818 - val_auc: 0.8600 - val_loss: 0.5914 - lr: 3.8000e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 4.5e-05.
# Epoch 6/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7366 - auc: 0.8014 - loss: 0.5436
# Epoch 00006: val_loss did not improve from 0.59145
# 28/28 [==============================] - 14s 511ms/step - accuracy: 0.7366 - auc: 0.8014 - loss: 0.5436 - val_accuracy: 0.6705 - val_auc: 0.8756 - val_loss: 0.5966 - lr: 4.5000e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 5.2000000000000004e-05.
# Epoch 7/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7299 - auc: 0.8069 - loss: 0.5389
# Epoch 00007: val_loss improved from 0.59145 to 0.50653, saving model to fold-1.h5
# 28/28 [==============================] - 5s 189ms/step - accuracy: 0.7299 - auc: 0.8069 - loss: 0.5389 - val_accuracy: 0.8040 - val_auc: 0.8864 - val_loss: 0.5065 - lr: 5.2000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 5.9000000000000004e-05.
# Epoch 8/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7444 - auc: 0.8344 - loss: 0.5019
# Epoch 00008: val_loss improved from 0.50653 to 0.50302, saving model to fold-1.h5
# 28/28 [==============================] - 5s 189ms/step - accuracy: 0.7444 - auc: 0.8344 - loss: 0.5019 - val_accuracy: 0.7898 - val_auc: 0.8892 - val_loss: 0.5030 - lr: 5.9000e-05
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 6.6e-05.
# Epoch 9/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7768 - auc: 0.8457 - loss: 0.4890
# Epoch 00009: val_loss improved from 0.50302 to 0.45696, saving model to fold-1.h5
# 28/28 [==============================] - 5s 184ms/step - accuracy: 0.7768 - auc: 0.8457 - loss: 0.4890 - val_accuracy: 0.8097 - val_auc: 0.9078 - val_loss: 0.4570 - lr: 6.6000e-05
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 7.300000000000001e-05.
# Epoch 10/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7444 - auc: 0.8301 - loss: 0.5058
# Epoch 00010: val_loss did not improve from 0.45696
# 28/28 [==============================] - 3s 121ms/step - accuracy: 0.7444 - auc: 0.8301 - loss: 0.5058 - val_accuracy: 0.7983 - val_auc: 0.9002 - val_loss: 0.4879 - lr: 7.3000e-05
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 8e-05.
# Epoch 11/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7757 - auc: 0.8561 - loss: 0.4691
# Epoch 00011: val_loss improved from 0.45696 to 0.43496, saving model to fold-1.h5
# 28/28 [==============================] - 5s 190ms/step - accuracy: 0.7757 - auc: 0.8561 - loss: 0.4691 - val_accuracy: 0.8267 - val_auc: 0.9116 - val_loss: 0.4350 - lr: 8.0000e-05
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 8.7e-05.
# Epoch 12/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7902 - auc: 0.8683 - loss: 0.4536
# Epoch 00012: val_loss did not improve from 0.43496
# 28/28 [==============================] - 3s 119ms/step - accuracy: 0.7902 - auc: 0.8683 - loss: 0.4536 - val_accuracy: 0.8125 - val_auc: 0.9125 - val_loss: 0.4478 - lr: 8.7000e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 9.400000000000001e-05.
# Epoch 13/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7489 - auc: 0.8308 - loss: 0.5081
# Epoch 00013: val_loss improved from 0.43496 to 0.43174, saving model to fold-1.h5
# 28/28 [==============================] - 5s 187ms/step - accuracy: 0.7489 - auc: 0.8308 - loss: 0.5081 - val_accuracy: 0.8210 - val_auc: 0.9190 - val_loss: 0.4317 - lr: 9.4000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00010100000000000002.
# Epoch 14/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7846 - auc: 0.8459 - loss: 0.4820
# Epoch 00014: val_loss did not improve from 0.43174
# 28/28 [==============================] - 3s 116ms/step - accuracy: 0.7846 - auc: 0.8459 - loss: 0.4820 - val_accuracy: 0.7869 - val_auc: 0.9098 - val_loss: 0.4685 - lr: 1.0100e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00010800000000000001.
# Epoch 15/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7623 - auc: 0.8489 - loss: 0.4786
# Epoch 00015: val_loss improved from 0.43174 to 0.41205, saving model to fold-1.h5
# 28/28 [==============================] - 5s 181ms/step - accuracy: 0.7623 - auc: 0.8489 - loss: 0.4786 - val_accuracy: 0.8267 - val_auc: 0.9176 - val_loss: 0.4120 - lr: 1.0800e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.000115.
# Epoch 16/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8092 - auc: 0.8721 - loss: 0.4472
# Epoch 00016: val_loss improved from 0.41205 to 0.37001, saving model to fold-1.h5
# 28/28 [==============================] - 5s 191ms/step - accuracy: 0.8092 - auc: 0.8721 - loss: 0.4472 - val_accuracy: 0.8324 - val_auc: 0.9266 - val_loss: 0.3700 - lr: 1.1500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00012200000000000001.
# Epoch 17/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7623 - auc: 0.8407 - loss: 0.4898
# Epoch 00017: val_loss did not improve from 0.37001
# 28/28 [==============================] - 3s 118ms/step - accuracy: 0.7623 - auc: 0.8407 - loss: 0.4898 - val_accuracy: 0.8324 - val_auc: 0.9207 - val_loss: 0.3968 - lr: 1.2200e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00012900000000000002.
# Epoch 18/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8025 - auc: 0.8841 - loss: 0.4254
# Epoch 00018: val_loss improved from 0.37001 to 0.36510, saving model to fold-1.h5
# 28/28 [==============================] - 5s 188ms/step - accuracy: 0.8025 - auc: 0.8841 - loss: 0.4254 - val_accuracy: 0.8551 - val_auc: 0.9218 - val_loss: 0.3651 - lr: 1.2900e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00013600000000000003.
# Epoch 19/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7913 - auc: 0.8710 - loss: 0.4470
# Epoch 00019: val_loss did not improve from 0.36510
# 28/28 [==============================] - 3s 113ms/step - accuracy: 0.7913 - auc: 0.8710 - loss: 0.4470 - val_accuracy: 0.8409 - val_auc: 0.9273 - val_loss: 0.3858 - lr: 1.3600e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.000143.
# Epoch 20/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8036 - auc: 0.8811 - loss: 0.4272
# Epoch 00020: val_loss improved from 0.36510 to 0.35874, saving model to fold-1.h5
# 28/28 [==============================] - 5s 184ms/step - accuracy: 0.8036 - auc: 0.8811 - loss: 0.4272 - val_accuracy: 0.8580 - val_auc: 0.9346 - val_loss: 0.3587 - lr: 1.4300e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 21/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7891 - auc: 0.8655 - loss: 0.4543
# Epoch 00021: val_loss improved from 0.35874 to 0.35789, saving model to fold-1.h5
# 28/28 [==============================] - 5s 188ms/step - accuracy: 0.7891 - auc: 0.8655 - loss: 0.4543 - val_accuracy: 0.8523 - val_auc: 0.9322 - val_loss: 0.3579 - lr: 1.5000e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 22/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7879 - auc: 0.8775 - loss: 0.4324
# Epoch 00022: val_loss improved from 0.35789 to 0.35108, saving model to fold-1.h5
# 28/28 [==============================] - 5s 179ms/step - accuracy: 0.7879 - auc: 0.8775 - loss: 0.4324 - val_accuracy: 0.8523 - val_auc: 0.9266 - val_loss: 0.3511 - lr: 1.5000e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 23/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8069 - auc: 0.8732 - loss: 0.4462
# Epoch 00023: val_loss did not improve from 0.35108
# 28/28 [==============================] - 3s 119ms/step - accuracy: 0.8069 - auc: 0.8732 - loss: 0.4462 - val_accuracy: 0.8409 - val_auc: 0.9280 - val_loss: 0.3786 - lr: 1.5000e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 24/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.7969 - auc: 0.8844 - loss: 0.4224
# Epoch 00024: val_loss improved from 0.35108 to 0.33208, saving model to fold-1.h5
# 28/28 [==============================] - 5s 183ms/step - accuracy: 0.7969 - auc: 0.8844 - loss: 0.4224 - val_accuracy: 0.8693 - val_auc: 0.9402 - val_loss: 0.3321 - lr: 1.5000e-04
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 25/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8036 - auc: 0.8768 - loss: 0.4377
# Epoch 00025: val_loss improved from 0.33208 to 0.32894, saving model to fold-1.h5
# 28/28 [==============================] - 5s 179ms/step - accuracy: 0.8036 - auc: 0.8768 - loss: 0.4377 - val_accuracy: 0.8608 - val_auc: 0.9326 - val_loss: 0.3289 - lr: 1.5000e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 26/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8170 - auc: 0.8922 - loss: 0.4094
# Epoch 00026: val_loss did not improve from 0.32894
# 28/28 [==============================] - 3s 115ms/step - accuracy: 0.8170 - auc: 0.8922 - loss: 0.4094 - val_accuracy: 0.8608 - val_auc: 0.9392 - val_loss: 0.3314 - lr: 1.5000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 27/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8114 - auc: 0.8840 - loss: 0.4191
# Epoch 00027: val_loss improved from 0.32894 to 0.30263, saving model to fold-1.h5
# 28/28 [==============================] - 5s 187ms/step - accuracy: 0.8114 - auc: 0.8840 - loss: 0.4191 - val_accuracy: 0.8665 - val_auc: 0.9428 - val_loss: 0.3026 - lr: 1.5000e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 28/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8192 - auc: 0.8973 - loss: 0.4007
# Epoch 00028: val_loss improved from 0.30263 to 0.29396, saving model to fold-1.h5
# 28/28 [==============================] - 5s 190ms/step - accuracy: 0.8192 - auc: 0.8973 - loss: 0.4007 - val_accuracy: 0.8693 - val_auc: 0.9467 - val_loss: 0.2940 - lr: 1.5000e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 29/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8315 - auc: 0.8915 - loss: 0.4068
# Epoch 00029: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 115ms/step - accuracy: 0.8315 - auc: 0.8915 - loss: 0.4068 - val_accuracy: 0.8750 - val_auc: 0.9484 - val_loss: 0.3109 - lr: 1.5000e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 30/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8304 - auc: 0.9016 - loss: 0.3865
# Epoch 00030: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 124ms/step - accuracy: 0.8304 - auc: 0.9016 - loss: 0.3865 - val_accuracy: 0.8210 - val_auc: 0.9405 - val_loss: 0.3854 - lr: 1.5000e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 31/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8225 - auc: 0.9000 - loss: 0.3895
# Epoch 00031: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 124ms/step - accuracy: 0.8225 - auc: 0.9000 - loss: 0.3895 - val_accuracy: 0.8068 - val_auc: 0.9377 - val_loss: 0.3846 - lr: 1.5000e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00012200000000000001.
# Epoch 32/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8382 - auc: 0.9118 - loss: 0.3730
# Epoch 00032: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 115ms/step - accuracy: 0.8382 - auc: 0.9118 - loss: 0.3730 - val_accuracy: 0.8665 - val_auc: 0.9411 - val_loss: 0.3298 - lr: 1.2200e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 9.960000000000002e-05.
# Epoch 33/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8583 - auc: 0.9185 - loss: 0.3520
# Epoch 00033: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 112ms/step - accuracy: 0.8583 - auc: 0.9185 - loss: 0.3520 - val_accuracy: 0.8665 - val_auc: 0.9446 - val_loss: 0.3180 - lr: 9.9600e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 8.168000000000002e-05.
# Epoch 34/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8348 - auc: 0.9065 - loss: 0.3785
# Epoch 00034: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 119ms/step - accuracy: 0.8348 - auc: 0.9065 - loss: 0.3785 - val_accuracy: 0.8580 - val_auc: 0.9427 - val_loss: 0.3227 - lr: 8.1680e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.734400000000002e-05.
# Epoch 35/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8516 - auc: 0.9168 - loss: 0.3608
# Epoch 00035: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 113ms/step - accuracy: 0.8516 - auc: 0.9168 - loss: 0.3608 - val_accuracy: 0.8693 - val_auc: 0.9481 - val_loss: 0.3092 - lr: 6.7344e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 5.587520000000002e-05.
# Epoch 36/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8571 - auc: 0.9178 - loss: 0.3644
# Epoch 00036: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 116ms/step - accuracy: 0.8571 - auc: 0.9178 - loss: 0.3644 - val_accuracy: 0.8551 - val_auc: 0.9488 - val_loss: 0.3148 - lr: 5.5875e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 4.6700160000000015e-05.
# Epoch 37/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8225 - auc: 0.9088 - loss: 0.3757
# Epoch 00037: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 120ms/step - accuracy: 0.8225 - auc: 0.9088 - loss: 0.3757 - val_accuracy: 0.8551 - val_auc: 0.9488 - val_loss: 0.3069 - lr: 4.6700e-05
# Epoch 00038: LearningRateScheduler reducing learning rate to 3.936012800000001e-05.
# Epoch 38/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8482 - auc: 0.9217 - loss: 0.3524
# Epoch 00038: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 115ms/step - accuracy: 0.8482 - auc: 0.9217 - loss: 0.3524 - val_accuracy: 0.8580 - val_auc: 0.9468 - val_loss: 0.3135 - lr: 3.9360e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 3.3488102400000014e-05.
# Epoch 39/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8359 - auc: 0.9034 - loss: 0.3842
# Epoch 00039: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 121ms/step - accuracy: 0.8359 - auc: 0.9034 - loss: 0.3842 - val_accuracy: 0.8551 - val_auc: 0.9484 - val_loss: 0.3174 - lr: 3.3488e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.8790481920000014e-05.
# Epoch 40/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8471 - auc: 0.9249 - loss: 0.3451
# Epoch 00040: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 124ms/step - accuracy: 0.8471 - auc: 0.9249 - loss: 0.3451 - val_accuracy: 0.8466 - val_auc: 0.9486 - val_loss: 0.3357 - lr: 2.8790e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.503238553600001e-05.
# Epoch 41/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8348 - auc: 0.9216 - loss: 0.3458
# Epoch 00041: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 115ms/step - accuracy: 0.8348 - auc: 0.9216 - loss: 0.3458 - val_accuracy: 0.8580 - val_auc: 0.9515 - val_loss: 0.3097 - lr: 2.5032e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.202590842880001e-05.
# Epoch 42/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8538 - auc: 0.9172 - loss: 0.3545
# Epoch 00042: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 114ms/step - accuracy: 0.8538 - auc: 0.9172 - loss: 0.3545 - val_accuracy: 0.8608 - val_auc: 0.9500 - val_loss: 0.3163 - lr: 2.2026e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 1.9620726743040006e-05.
# Epoch 43/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8326 - auc: 0.9080 - loss: 0.3783
# Epoch 00043: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 122ms/step - accuracy: 0.8326 - auc: 0.9080 - loss: 0.3783 - val_accuracy: 0.8580 - val_auc: 0.9500 - val_loss: 0.3245 - lr: 1.9621e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 1.769658139443201e-05.
# Epoch 44/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8605 - auc: 0.9281 - loss: 0.3371
# Epoch 00044: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 114ms/step - accuracy: 0.8605 - auc: 0.9281 - loss: 0.3371 - val_accuracy: 0.8466 - val_auc: 0.9497 - val_loss: 0.3375 - lr: 1.7697e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 1.6157265115545607e-05.
# Epoch 45/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8415 - auc: 0.9218 - loss: 0.3452
# Epoch 00045: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 114ms/step - accuracy: 0.8415 - auc: 0.9218 - loss: 0.3452 - val_accuracy: 0.8438 - val_auc: 0.9486 - val_loss: 0.3395 - lr: 1.6157e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.4925812092436487e-05.
# Epoch 46/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8672 - auc: 0.9262 - loss: 0.3380
# Epoch 00046: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 120ms/step - accuracy: 0.8672 - auc: 0.9262 - loss: 0.3380 - val_accuracy: 0.8523 - val_auc: 0.9495 - val_loss: 0.3272 - lr: 1.4926e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.3940649673949189e-05.
# Epoch 47/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8460 - auc: 0.9148 - loss: 0.3599
# Epoch 00047: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 112ms/step - accuracy: 0.8460 - auc: 0.9148 - loss: 0.3599 - val_accuracy: 0.8693 - val_auc: 0.9577 - val_loss: 0.2988 - lr: 1.3941e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3152519739159351e-05.
# Epoch 48/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8728 - auc: 0.9393 - loss: 0.3114
# Epoch 00048: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 116ms/step - accuracy: 0.8728 - auc: 0.9393 - loss: 0.3114 - val_accuracy: 0.8722 - val_auc: 0.9521 - val_loss: 0.3063 - lr: 1.3153e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.252201579132748e-05.
# Epoch 49/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8549 - auc: 0.9303 - loss: 0.3371
# Epoch 00049: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 118ms/step - accuracy: 0.8549 - auc: 0.9303 - loss: 0.3371 - val_accuracy: 0.8665 - val_auc: 0.9522 - val_loss: 0.3063 - lr: 1.2522e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.2017612633061985e-05.
# Epoch 50/50
# 28/28 [==============================] - ETA: 0s - accuracy: 0.8650 - auc: 0.9333 - loss: 0.3240
# Epoch 00050: val_loss did not improve from 0.29396
# 28/28 [==============================] - 3s 122ms/step - accuracy: 0.8650 - auc: 0.9333 - loss: 0.3240 - val_accuracy: 0.8665 - val_auc: 0.9533 - val_loss: 0.3057 - lr: 1.2018e-05
#
# Time (sec) elapsed:  373.8
# ...
# ...
#
# ############################################################
# #### FOLD 2
# #### Image Size 256, EfficientNet B2, batch_size 256
# #### Epochs: 50
# ############################################################
# Number of training images 9000
# Number of validation images 1280
# Building model...
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.5312 - auc: 0.5400 - loss: 0.6909
# Epoch 00001: val_loss improved from inf to 0.71551, saving model to fold-2.h5
# 35/35 [==============================] - 16s 458ms/step - accuracy: 0.5312 - auc: 0.5400 - loss: 0.6909 - val_accuracy: 0.4938 - val_auc: 0.5912 - val_loss: 0.7155 - lr: 1.0000e-05
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 1.7e-05.
# Epoch 2/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.6179 - auc: 0.6730 - loss: 0.6551
# Epoch 00002: val_loss improved from 0.71551 to 0.65524, saving model to fold-2.h5
# 35/35 [==============================] - 5s 152ms/step - accuracy: 0.6179 - auc: 0.6730 - loss: 0.6551 - val_accuracy: 0.5500 - val_auc: 0.7645 - val_loss: 0.6552 - lr: 1.7000e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 2.4e-05.
# Epoch 3/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.6902 - auc: 0.7600 - loss: 0.6100
# Epoch 00003: val_loss improved from 0.65524 to 0.60796, saving model to fold-2.h5
# 35/35 [==============================] - 6s 161ms/step - accuracy: 0.6902 - auc: 0.7600 - loss: 0.6100 - val_accuracy: 0.6875 - val_auc: 0.8361 - val_loss: 0.6080 - lr: 2.4000e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 3.1e-05.
# Epoch 4/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7196 - auc: 0.7793 - loss: 0.5756
# Epoch 00004: val_loss improved from 0.60796 to 0.55857, saving model to fold-2.h5
# 35/35 [==============================] - 5s 153ms/step - accuracy: 0.7196 - auc: 0.7793 - loss: 0.5756 - val_accuracy: 0.7937 - val_auc: 0.8636 - val_loss: 0.5586 - lr: 3.1000e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 3.8e-05.
# Epoch 5/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7393 - auc: 0.8060 - loss: 0.5446
# Epoch 00005: val_loss improved from 0.55857 to 0.53712, saving model to fold-2.h5
# 35/35 [==============================] - 6s 159ms/step - accuracy: 0.7393 - auc: 0.8060 - loss: 0.5446 - val_accuracy: 0.7812 - val_auc: 0.8643 - val_loss: 0.5371 - lr: 3.8000e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 4.5e-05.
# Epoch 6/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7357 - auc: 0.8202 - loss: 0.5243
# Epoch 00006: val_loss improved from 0.53712 to 0.52138, saving model to fold-2.h5
# 35/35 [==============================] - 5s 156ms/step - accuracy: 0.7357 - auc: 0.8202 - loss: 0.5243 - val_accuracy: 0.7688 - val_auc: 0.8644 - val_loss: 0.5214 - lr: 4.5000e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 5.2000000000000004e-05.
# Epoch 7/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7571 - auc: 0.8370 - loss: 0.5004
# Epoch 00007: val_loss improved from 0.52138 to 0.49614, saving model to fold-2.h5
# 35/35 [==============================] - 6s 159ms/step - accuracy: 0.7571 - auc: 0.8370 - loss: 0.5004 - val_accuracy: 0.7688 - val_auc: 0.8705 - val_loss: 0.4961 - lr: 5.2000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 5.9000000000000004e-05.
# Epoch 8/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7554 - auc: 0.8340 - loss: 0.5021
# Epoch 00008: val_loss improved from 0.49614 to 0.46529, saving model to fold-2.h5
# 35/35 [==============================] - 5s 156ms/step - accuracy: 0.7554 - auc: 0.8340 - loss: 0.5021 - val_accuracy: 0.7812 - val_auc: 0.8794 - val_loss: 0.4653 - lr: 5.9000e-05
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 6.6e-05.
# Epoch 9/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7670 - auc: 0.8381 - loss: 0.4964
# Epoch 00009: val_loss did not improve from 0.46529
# 35/35 [==============================] - 4s 107ms/step - accuracy: 0.7670 - auc: 0.8381 - loss: 0.4964 - val_accuracy: 0.7625 - val_auc: 0.8766 - val_loss: 0.4843 - lr: 6.6000e-05
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 7.300000000000001e-05.
# Epoch 10/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7705 - auc: 0.8487 - loss: 0.4767
# Epoch 00010: val_loss improved from 0.46529 to 0.44387, saving model to fold-2.h5
# 35/35 [==============================] - 5s 155ms/step - accuracy: 0.7705 - auc: 0.8487 - loss: 0.4767 - val_accuracy: 0.8188 - val_auc: 0.8943 - val_loss: 0.4439 - lr: 7.3000e-05
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 8e-05.
# Epoch 11/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7732 - auc: 0.8514 - loss: 0.4754
# Epoch 00011: val_loss improved from 0.44387 to 0.40972, saving model to fold-2.h5
# 35/35 [==============================] - 6s 158ms/step - accuracy: 0.7732 - auc: 0.8514 - loss: 0.4754 - val_accuracy: 0.8313 - val_auc: 0.9060 - val_loss: 0.4097 - lr: 8.0000e-05
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 8.7e-05.
# Epoch 12/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7696 - auc: 0.8475 - loss: 0.4825
# Epoch 00012: val_loss improved from 0.40972 to 0.39923, saving model to fold-2.h5
# 35/35 [==============================] - 6s 158ms/step - accuracy: 0.7696 - auc: 0.8475 - loss: 0.4825 - val_accuracy: 0.8250 - val_auc: 0.9121 - val_loss: 0.3992 - lr: 8.7000e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 9.400000000000001e-05.
# Epoch 13/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7768 - auc: 0.8499 - loss: 0.4805
# Epoch 00013: val_loss did not improve from 0.39923
# 35/35 [==============================] - 4s 103ms/step - accuracy: 0.7768 - auc: 0.8499 - loss: 0.4805 - val_accuracy: 0.8375 - val_auc: 0.9176 - val_loss: 0.4157 - lr: 9.4000e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00010100000000000002.
# Epoch 14/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7884 - auc: 0.8570 - loss: 0.4711
# Epoch 00014: val_loss improved from 0.39923 to 0.38489, saving model to fold-2.h5
# 35/35 [==============================] - 6s 163ms/step - accuracy: 0.7884 - auc: 0.8570 - loss: 0.4711 - val_accuracy: 0.8500 - val_auc: 0.9150 - val_loss: 0.3849 - lr: 1.0100e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00010800000000000001.
# Epoch 15/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7839 - auc: 0.8670 - loss: 0.4519
# Epoch 00015: val_loss improved from 0.38489 to 0.37452, saving model to fold-2.h5
# 35/35 [==============================] - 6s 164ms/step - accuracy: 0.7839 - auc: 0.8670 - loss: 0.4519 - val_accuracy: 0.8375 - val_auc: 0.9136 - val_loss: 0.3745 - lr: 1.0800e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.000115.
# Epoch 16/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7688 - auc: 0.8512 - loss: 0.4774
# Epoch 00016: val_loss did not improve from 0.37452
# 35/35 [==============================] - 4s 108ms/step - accuracy: 0.7688 - auc: 0.8512 - loss: 0.4774 - val_accuracy: 0.7937 - val_auc: 0.9140 - val_loss: 0.4567 - lr: 1.1500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00012200000000000001.
# Epoch 17/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8000 - auc: 0.8870 - loss: 0.4216
# Epoch 00017: val_loss improved from 0.37452 to 0.34788, saving model to fold-2.h5
# 35/35 [==============================] - 6s 161ms/step - accuracy: 0.8000 - auc: 0.8870 - loss: 0.4216 - val_accuracy: 0.8438 - val_auc: 0.9330 - val_loss: 0.3479 - lr: 1.2200e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00012900000000000002.
# Epoch 18/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7857 - auc: 0.8674 - loss: 0.4507
# Epoch 00018: val_loss improved from 0.34788 to 0.34367, saving model to fold-2.h5
# 35/35 [==============================] - 6s 162ms/step - accuracy: 0.7857 - auc: 0.8674 - loss: 0.4507 - val_accuracy: 0.8688 - val_auc: 0.9267 - val_loss: 0.3437 - lr: 1.2900e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00013600000000000003.
# Epoch 19/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7839 - auc: 0.8704 - loss: 0.4459
# Epoch 00019: val_loss did not improve from 0.34367
# 35/35 [==============================] - 4s 104ms/step - accuracy: 0.7839 - auc: 0.8704 - loss: 0.4459 - val_accuracy: 0.8250 - val_auc: 0.9237 - val_loss: 0.3559 - lr: 1.3600e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.000143.
# Epoch 20/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8045 - auc: 0.8779 - loss: 0.4314
# Epoch 00020: val_loss did not improve from 0.34367
# 35/35 [==============================] - 4s 106ms/step - accuracy: 0.8045 - auc: 0.8779 - loss: 0.4314 - val_accuracy: 0.8188 - val_auc: 0.9189 - val_loss: 0.3657 - lr: 1.4300e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 21/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8062 - auc: 0.8714 - loss: 0.4366
# Epoch 00021: val_loss did not improve from 0.34367
# 35/35 [==============================] - 4s 105ms/step - accuracy: 0.8062 - auc: 0.8714 - loss: 0.4366 - val_accuracy: 0.8313 - val_auc: 0.9226 - val_loss: 0.3652 - lr: 1.5000e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 22/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8045 - auc: 0.8801 - loss: 0.4267
# Epoch 00022: val_loss improved from 0.34367 to 0.33027, saving model to fold-2.h5
# 35/35 [==============================] - 6s 158ms/step - accuracy: 0.8045 - auc: 0.8801 - loss: 0.4267 - val_accuracy: 0.8625 - val_auc: 0.9321 - val_loss: 0.3303 - lr: 1.5000e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 23/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7875 - auc: 0.8657 - loss: 0.4531
# Epoch 00023: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 108ms/step - accuracy: 0.7875 - auc: 0.8657 - loss: 0.4531 - val_accuracy: 0.8375 - val_auc: 0.9279 - val_loss: 0.3391 - lr: 1.5000e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 24/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8009 - auc: 0.8839 - loss: 0.4257
# Epoch 00024: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 106ms/step - accuracy: 0.8009 - auc: 0.8839 - loss: 0.4257 - val_accuracy: 0.7937 - val_auc: 0.9293 - val_loss: 0.4297 - lr: 1.5000e-04
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 25/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.7902 - auc: 0.8725 - loss: 0.4381
# Epoch 00025: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 106ms/step - accuracy: 0.7902 - auc: 0.8725 - loss: 0.4381 - val_accuracy: 0.8313 - val_auc: 0.9317 - val_loss: 0.3697 - lr: 1.5000e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 26/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8241 - auc: 0.8960 - loss: 0.4019
# Epoch 00026: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 101ms/step - accuracy: 0.8241 - auc: 0.8960 - loss: 0.4019 - val_accuracy: 0.8250 - val_auc: 0.9353 - val_loss: 0.3370 - lr: 1.5000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 27/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8107 - auc: 0.8920 - loss: 0.4013
# Epoch 00027: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 102ms/step - accuracy: 0.8107 - auc: 0.8920 - loss: 0.4013 - val_accuracy: 0.8500 - val_auc: 0.9304 - val_loss: 0.3333 - lr: 1.5000e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 28/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8393 - auc: 0.9039 - loss: 0.3800
# Epoch 00028: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 106ms/step - accuracy: 0.8393 - auc: 0.9039 - loss: 0.3800 - val_accuracy: 0.8500 - val_auc: 0.9283 - val_loss: 0.3429 - lr: 1.5000e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 29/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8313 - auc: 0.9120 - loss: 0.3725
# Epoch 00029: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 111ms/step - accuracy: 0.8313 - auc: 0.9120 - loss: 0.3725 - val_accuracy: 0.8313 - val_auc: 0.9221 - val_loss: 0.3701 - lr: 1.5000e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 30/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8295 - auc: 0.9027 - loss: 0.3815
# Epoch 00030: val_loss did not improve from 0.33027
# 35/35 [==============================] - 4s 104ms/step - accuracy: 0.8295 - auc: 0.9027 - loss: 0.3815 - val_accuracy: 0.8625 - val_auc: 0.9313 - val_loss: 0.3366 - lr: 1.5000e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 31/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8500 - auc: 0.9139 - loss: 0.3603
# Epoch 00031: val_loss improved from 0.33027 to 0.29249, saving model to fold-2.h5
# 35/35 [==============================] - 6s 166ms/step - accuracy: 0.8500 - auc: 0.9139 - loss: 0.3603 - val_accuracy: 0.8938 - val_auc: 0.9581 - val_loss: 0.2925 - lr: 1.5000e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00012200000000000001.
# Epoch 32/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8321 - auc: 0.9050 - loss: 0.3781
# Epoch 00032: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 103ms/step - accuracy: 0.8321 - auc: 0.9050 - loss: 0.3781 - val_accuracy: 0.8625 - val_auc: 0.9511 - val_loss: 0.3089 - lr: 1.2200e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 9.960000000000002e-05.
# Epoch 33/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8464 - auc: 0.9067 - loss: 0.3764
# Epoch 00033: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 104ms/step - accuracy: 0.8464 - auc: 0.9067 - loss: 0.3764 - val_accuracy: 0.8375 - val_auc: 0.9411 - val_loss: 0.2994 - lr: 9.9600e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 8.168000000000002e-05.
# Epoch 34/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8491 - auc: 0.9061 - loss: 0.3680
# Epoch 00034: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 103ms/step - accuracy: 0.8491 - auc: 0.9061 - loss: 0.3680 - val_accuracy: 0.8438 - val_auc: 0.9408 - val_loss: 0.3239 - lr: 8.1680e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.734400000000002e-05.
# Epoch 35/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8571 - auc: 0.9263 - loss: 0.3392
# Epoch 00035: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 104ms/step - accuracy: 0.8571 - auc: 0.9263 - loss: 0.3392 - val_accuracy: 0.8375 - val_auc: 0.9403 - val_loss: 0.3128 - lr: 6.7344e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 5.587520000000002e-05.
# Epoch 36/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8473 - auc: 0.9159 - loss: 0.3578
# Epoch 00036: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 103ms/step - accuracy: 0.8473 - auc: 0.9159 - loss: 0.3578 - val_accuracy: 0.8750 - val_auc: 0.9465 - val_loss: 0.3032 - lr: 5.5875e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 4.6700160000000015e-05.
# Epoch 37/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8634 - auc: 0.9185 - loss: 0.3453
# Epoch 00037: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 107ms/step - accuracy: 0.8634 - auc: 0.9185 - loss: 0.3453 - val_accuracy: 0.8625 - val_auc: 0.9481 - val_loss: 0.2999 - lr: 4.6700e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 3.936012800000001e-05.
# Epoch 38/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8446 - auc: 0.9139 - loss: 0.3559
# Epoch 00038: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 101ms/step - accuracy: 0.8446 - auc: 0.9139 - loss: 0.3559 - val_accuracy: 0.8813 - val_auc: 0.9447 - val_loss: 0.3099 - lr: 3.9360e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 3.3488102400000014e-05.
# Epoch 39/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8580 - auc: 0.9205 - loss: 0.3491
# Epoch 00039: val_loss did not improve from 0.29249
# 35/35 [==============================] - 5s 144ms/step - accuracy: 0.8580 - auc: 0.9205 - loss: 0.3491 - val_accuracy: 0.8625 - val_auc: 0.9374 - val_loss: 0.3089 - lr: 3.3488e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.8790481920000014e-05.
# Epoch 40/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8634 - auc: 0.9380 - loss: 0.3139
# Epoch 00040: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 102ms/step - accuracy: 0.8634 - auc: 0.9380 - loss: 0.3139 - val_accuracy: 0.8813 - val_auc: 0.9447 - val_loss: 0.3036 - lr: 2.8790e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.503238553600001e-05.
# Epoch 41/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8429 - auc: 0.9234 - loss: 0.3411
# Epoch 00041: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 103ms/step - accuracy: 0.8429 - auc: 0.9234 - loss: 0.3411 - val_accuracy: 0.8813 - val_auc: 0.9426 - val_loss: 0.3014 - lr: 2.5032e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.202590842880001e-05.
# Epoch 42/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8518 - auc: 0.9255 - loss: 0.3364
# Epoch 00042: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 110ms/step - accuracy: 0.8518 - auc: 0.9255 - loss: 0.3364 - val_accuracy: 0.8688 - val_auc: 0.9487 - val_loss: 0.2951 - lr: 2.2026e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 1.9620726743040006e-05.
# Epoch 43/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8634 - auc: 0.9302 - loss: 0.3285
# Epoch 00043: val_loss did not improve from 0.29249
# 35/35 [==============================] - 4s 105ms/step - accuracy: 0.8634 - auc: 0.9302 - loss: 0.3285 - val_accuracy: 0.8750 - val_auc: 0.9458 - val_loss: 0.2972 - lr: 1.9621e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 1.769658139443201e-05.
# Epoch 44/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8554 - auc: 0.9272 - loss: 0.3289
# Epoch 00044: val_loss improved from 0.29249 to 0.29079, saving model to fold-2.h5
# 35/35 [==============================] - 6s 161ms/step - accuracy: 0.8554 - auc: 0.9272 - loss: 0.3289 - val_accuracy: 0.8813 - val_auc: 0.9487 - val_loss: 0.2908 - lr: 1.7697e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 1.6157265115545607e-05.
# Epoch 45/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8464 - auc: 0.9243 - loss: 0.3399
# Epoch 00045: val_loss improved from 0.29079 to 0.29044, saving model to fold-2.h5
# 35/35 [==============================] - 5s 155ms/step - accuracy: 0.8464 - auc: 0.9243 - loss: 0.3399 - val_accuracy: 0.8750 - val_auc: 0.9469 - val_loss: 0.2904 - lr: 1.6157e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.4925812092436487e-05.
# Epoch 46/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8562 - auc: 0.9185 - loss: 0.3427
# Epoch 00046: val_loss improved from 0.29044 to 0.28740, saving model to fold-2.h5
# 35/35 [==============================] - 6s 159ms/step - accuracy: 0.8562 - auc: 0.9185 - loss: 0.3427 - val_accuracy: 0.8938 - val_auc: 0.9488 - val_loss: 0.2874 - lr: 1.4926e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.3940649673949189e-05.
# Epoch 47/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8679 - auc: 0.9345 - loss: 0.3131
# Epoch 00047: val_loss improved from 0.28740 to 0.28524, saving model to fold-2.h5
# 35/35 [==============================] - 6s 162ms/step - accuracy: 0.8679 - auc: 0.9345 - loss: 0.3131 - val_accuracy: 0.8813 - val_auc: 0.9491 - val_loss: 0.2852 - lr: 1.3941e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3152519739159351e-05.
# Epoch 48/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8607 - auc: 0.9327 - loss: 0.3192
# Epoch 00048: val_loss did not improve from 0.28524
# 35/35 [==============================] - 4s 103ms/step - accuracy: 0.8607 - auc: 0.9327 - loss: 0.3192 - val_accuracy: 0.8750 - val_auc: 0.9494 - val_loss: 0.2913 - lr: 1.3153e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.252201579132748e-05.
# Epoch 49/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8545 - auc: 0.9225 - loss: 0.3432
# Epoch 00049: val_loss did not improve from 0.28524
# 35/35 [==============================] - 4s 104ms/step - accuracy: 0.8545 - auc: 0.9225 - loss: 0.3432 - val_accuracy: 0.8750 - val_auc: 0.9505 - val_loss: 0.2858 - lr: 1.2522e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.2017612633061985e-05.
# Epoch 50/50
# 35/35 [==============================] - ETA: 0s - accuracy: 0.8625 - auc: 0.9309 - loss: 0.3283
# Epoch 00050: val_loss improved from 0.28524 to 0.28279, saving model to fold-2.h5
# 35/35 [==============================] - 6s 165ms/step - accuracy: 0.8625 - auc: 0.9309 - loss: 0.3283 - val_accuracy: 0.8750 - val_auc: 0.9496 - val_loss: 0.2828 - lr: 1.2018e-05
#
# Time (sec) elapsed:  367.7
# ...
# ...
#
# ############################################################
# #### FOLD 3
# #### Image Size 256, EfficientNet B2, batch_size 256
# #### Epochs: 50
# ############################################################
# Number of training images 8280
# Number of validation images 2000
# Building model...
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.5479 - auc: 0.5612 - loss: 0.6877
# Epoch 00001: val_loss improved from inf to 0.69485, saving model to fold-3.h5
# 32/32 [==============================] - 16s 490ms/step - accuracy: 0.5479 - auc: 0.5612 - loss: 0.6877 - val_accuracy: 0.4821 - val_auc: 0.5489 - val_loss: 0.6948 - lr: 1.0000e-05
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 1.7e-05.
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.6680 - auc: 0.7210 - loss: 0.6465
# Epoch 00002: val_loss improved from 0.69485 to 0.67407, saving model to fold-3.h5
# 32/32 [==============================] - 6s 175ms/step - accuracy: 0.6680 - auc: 0.7210 - loss: 0.6465 - val_accuracy: 0.5402 - val_auc: 0.7144 - val_loss: 0.6741 - lr: 1.7000e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 2.4e-05.
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.6924 - auc: 0.7636 - loss: 0.6137
# Epoch 00003: val_loss improved from 0.67407 to 0.64248, saving model to fold-3.h5
# 32/32 [==============================] - 5s 166ms/step - accuracy: 0.6924 - auc: 0.7636 - loss: 0.6137 - val_accuracy: 0.5848 - val_auc: 0.8219 - val_loss: 0.6425 - lr: 2.4000e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 3.1e-05.
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7129 - auc: 0.7692 - loss: 0.5902
# Epoch 00004: val_loss improved from 0.64248 to 0.62171, saving model to fold-3.h5
# 32/32 [==============================] - 6s 176ms/step - accuracy: 0.7129 - auc: 0.7692 - loss: 0.5902 - val_accuracy: 0.6518 - val_auc: 0.8154 - val_loss: 0.6217 - lr: 3.1000e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 3.8e-05.
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7393 - auc: 0.7993 - loss: 0.5490
# Epoch 00005: val_loss improved from 0.62171 to 0.59449, saving model to fold-3.h5
# 32/32 [==============================] - 5s 165ms/step - accuracy: 0.7393 - auc: 0.7993 - loss: 0.5490 - val_accuracy: 0.6875 - val_auc: 0.8334 - val_loss: 0.5945 - lr: 3.8000e-05
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 4.5e-05.
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7451 - auc: 0.8148 - loss: 0.5309
# Epoch 00006: val_loss improved from 0.59449 to 0.57678, saving model to fold-3.h5
# 32/32 [==============================] - 6s 178ms/step - accuracy: 0.7451 - auc: 0.8148 - loss: 0.5309 - val_accuracy: 0.7143 - val_auc: 0.8463 - val_loss: 0.5768 - lr: 4.5000e-05
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 5.2000000000000004e-05.
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7510 - auc: 0.8320 - loss: 0.5059
# Epoch 00007: val_loss improved from 0.57678 to 0.56150, saving model to fold-3.h5
# 32/32 [==============================] - 5s 167ms/step - accuracy: 0.7510 - auc: 0.8320 - loss: 0.5059 - val_accuracy: 0.7321 - val_auc: 0.8626 - val_loss: 0.5615 - lr: 5.2000e-05
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 5.9000000000000004e-05.
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7432 - auc: 0.8269 - loss: 0.5139
# Epoch 00008: val_loss improved from 0.56150 to 0.53917, saving model to fold-3.h5
# ...
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00010100000000000002.
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7803 - auc: 0.8601 - loss: 0.4604
# Epoch 00014: val_loss did not improve from 0.39244
# 32/32 [==============================] - 3s 108ms/step - accuracy: 0.7803 - auc: 0.8601 - loss: 0.4604 - val_accuracy: 0.8170 - val_auc: 0.8987 - val_loss: 0.4208 - lr: 1.0100e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00010800000000000001.
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7783 - auc: 0.8489 - loss: 0.4856
# Epoch 00015: val_loss did not improve from 0.39244
# 32/32 [==============================] - 4s 115ms/step - accuracy: 0.7783 - auc: 0.8489 - loss: 0.4856 - val_accuracy: 0.8438 - val_auc: 0.9129 - val_loss: 0.4165 - lr: 1.0800e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.000115.
# Epoch 16/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7871 - auc: 0.8608 - loss: 0.4653
# Epoch 00016: val_loss improved from 0.39244 to 0.38387, saving model to fold-5.h5
# 32/32 [==============================] - 5s 163ms/step - accuracy: 0.7871 - auc: 0.8608 - loss: 0.4653 - val_accuracy: 0.8482 - val_auc: 0.8973 - val_loss: 0.3839 - lr: 1.1500e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00012200000000000001.
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8086 - auc: 0.8804 - loss: 0.4318
# Epoch 00017: val_loss did not improve from 0.38387
# 32/32 [==============================] - 4s 112ms/step - accuracy: 0.8086 - auc: 0.8804 - loss: 0.4318 - val_accuracy: 0.8214 - val_auc: 0.8930 - val_loss: 0.3961 - lr: 1.2200e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00012900000000000002.
# Epoch 18/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7803 - auc: 0.8485 - loss: 0.4825
# Epoch 00018: val_loss did not improve from 0.38387
# 32/32 [==============================] - 4s 110ms/step - accuracy: 0.7803 - auc: 0.8485 - loss: 0.4825 - val_accuracy: 0.8482 - val_auc: 0.9006 - val_loss: 0.3929 - lr: 1.2900e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00013600000000000003.
# Epoch 19/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7969 - auc: 0.8741 - loss: 0.4459
# Epoch 00019: val_loss did not improve from 0.38387
# 32/32 [==============================] - 3s 108ms/step - accuracy: 0.7969 - auc: 0.8741 - loss: 0.4459 - val_accuracy: 0.8214 - val_auc: 0.8999 - val_loss: 0.3885 - lr: 1.3600e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.000143.
# Epoch 20/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8057 - auc: 0.8762 - loss: 0.4375
# Epoch 00020: val_loss did not improve from 0.38387
# 32/32 [==============================] - 3s 106ms/step - accuracy: 0.8057 - auc: 0.8762 - loss: 0.4375 - val_accuracy: 0.8304 - val_auc: 0.8904 - val_loss: 0.3935 - lr: 1.4300e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 21/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7959 - auc: 0.8611 - loss: 0.4581
# Epoch 00021: val_loss did not improve from 0.38387
# 32/32 [==============================] - 4s 114ms/step - accuracy: 0.7959 - auc: 0.8611 - loss: 0.4581 - val_accuracy: 0.8214 - val_auc: 0.8970 - val_loss: 0.4117 - lr: 1.5000e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 22/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8164 - auc: 0.8783 - loss: 0.4353
# Epoch 00022: val_loss improved from 0.38387 to 0.35792, saving model to fold-5.h5
# 32/32 [==============================] - 5s 167ms/step - accuracy: 0.8164 - auc: 0.8783 - loss: 0.4353 - val_accuracy: 0.8304 - val_auc: 0.9241 - val_loss: 0.3579 - lr: 1.5000e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 23/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8164 - auc: 0.8902 - loss: 0.4153
# Epoch 00023: val_loss did not improve from 0.35792
# 32/32 [==============================] - 4s 121ms/step - accuracy: 0.8164 - auc: 0.8902 - loss: 0.4153 - val_accuracy: 0.8259 - val_auc: 0.9114 - val_loss: 0.3616 - lr: 1.5000e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 24/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8135 - auc: 0.8738 - loss: 0.4356
# Epoch 00024: val_loss improved from 0.35792 to 0.35125, saving model to fold-5.h5
# 32/32 [==============================] - 5s 161ms/step - accuracy: 0.8135 - auc: 0.8738 - loss: 0.4356 - val_accuracy: 0.8482 - val_auc: 0.9175 - val_loss: 0.3512 - lr: 1.5000e-04
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8262 - auc: 0.9043 - loss: 0.3917
# Epoch 00025: val_loss did not improve from 0.35125
# 32/32 [==============================] - 4s 109ms/step - accuracy: 0.8262 - auc: 0.9043 - loss: 0.3917 - val_accuracy: 0.8438 - val_auc: 0.9112 - val_loss: 0.3787 - lr: 1.5000e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.7959 - auc: 0.8771 - loss: 0.4314
# Epoch 00026: val_loss did not improve from 0.35125
# 32/32 [==============================] - 4s 112ms/step - accuracy: 0.7959 - auc: 0.8771 - loss: 0.4314 - val_accuracy: 0.8214 - val_auc: 0.9192 - val_loss: 0.3992 - lr: 1.5000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 27/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8359 - auc: 0.9034 - loss: 0.3853
# Epoch 00027: val_loss did not improve from 0.35125
# 32/32 [==============================] - 3s 106ms/step - accuracy: 0.8359 - auc: 0.9034 - loss: 0.3853 - val_accuracy: 0.8438 - val_auc: 0.9096 - val_loss: 0.3865 - lr: 1.5000e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 28/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8350 - auc: 0.9042 - loss: 0.3869
# Epoch 00028: val_loss did not improve from 0.35125
# 32/32 [==============================] - 4s 110ms/step - accuracy: 0.8350 - auc: 0.9042 - loss: 0.3869 - val_accuracy: 0.8527 - val_auc: 0.9124 - val_loss: 0.3549 - lr: 1.5000e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 29/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8223 - auc: 0.8939 - loss: 0.4040
# Epoch 00029: val_loss did not improve from 0.35125
# 32/32 [==============================] - 4s 111ms/step - accuracy: 0.8223 - auc: 0.8939 - loss: 0.4040 - val_accuracy: 0.8438 - val_auc: 0.9174 - val_loss: 0.3841 - lr: 1.5000e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8672 - auc: 0.9221 - loss: 0.3492
# Epoch 00030: val_loss improved from 0.35125 to 0.33896, saving model to fold-5.h5
# 32/32 [==============================] - 5s 169ms/step - accuracy: 0.8672 - auc: 0.9221 - loss: 0.3492 - val_accuracy: 0.8705 - val_auc: 0.9220 - val_loss: 0.3390 - lr: 1.5000e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.00015000000000000001.
# Epoch 31/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8086 - auc: 0.8903 - loss: 0.4058
# Epoch 00031: val_loss did not improve from 0.33896
# 32/32 [==============================] - 4s 113ms/step - accuracy: 0.8086 - auc: 0.8903 - loss: 0.4058 - val_accuracy: 0.8393 - val_auc: 0.9235 - val_loss: 0.3571 - lr: 1.5000e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00012200000000000001.
# Epoch 32/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8506 - auc: 0.9150 - loss: 0.3681
# Epoch 00032: val_loss did not improve from 0.33896
# 32/32 [==============================] - 4s 110ms/step - accuracy: 0.8506 - auc: 0.9150 - loss: 0.3681 - val_accuracy: 0.8438 - val_auc: 0.9161 - val_loss: 0.3673 - lr: 1.2200e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 9.960000000000002e-05.
# Epoch 33/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8545 - auc: 0.9259 - loss: 0.3408
# Epoch 00033: val_loss did not improve from 0.33896
# 32/32 [==============================] - 3s 106ms/step - accuracy: 0.8545 - auc: 0.9259 - loss: 0.3408 - val_accuracy: 0.8304 - val_auc: 0.9202 - val_loss: 0.3445 - lr: 9.9600e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 8.168000000000002e-05.
# Epoch 34/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8535 - auc: 0.9239 - loss: 0.3397
# Epoch 00034: val_loss did not improve from 0.33896
# 32/32 [==============================] - 4s 113ms/step - accuracy: 0.8535 - auc: 0.9239 - loss: 0.3397 - val_accuracy: 0.8438 - val_auc: 0.9206 - val_loss: 0.3420 - lr: 8.1680e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.734400000000002e-05.
# Epoch 35/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8320 - auc: 0.9093 - loss: 0.3682
# Epoch 00035: val_loss improved from 0.33896 to 0.33705, saving model to fold-5.h5
# 32/32 [==============================] - 5s 164ms/step - accuracy: 0.8320 - auc: 0.9093 - loss: 0.3682 - val_accuracy: 0.8482 - val_auc: 0.9233 - val_loss: 0.3371 - lr: 6.7344e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 5.587520000000002e-05.
# Epoch 36/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8525 - auc: 0.9140 - loss: 0.3546
# Epoch 00036: val_loss did not improve from 0.33705
# 32/32 [==============================] - 3s 109ms/step - accuracy: 0.8525 - auc: 0.9140 - loss: 0.3546 - val_accuracy: 0.8438 - val_auc: 0.9216 - val_loss: 0.3472 - lr: 5.5875e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 4.6700160000000015e-05.
# Epoch 37/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8457 - auc: 0.9167 - loss: 0.3584
# Epoch 00037: val_loss improved from 0.33705 to 0.33406, saving model to fold-5.h5
# 32/32 [==============================] - 6s 176ms/step - accuracy: 0.8457 - auc: 0.9167 - loss: 0.3584 - val_accuracy: 0.8348 - val_auc: 0.9238 - val_loss: 0.3341 - lr: 4.6700e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 3.936012800000001e-05.
# Epoch 38/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8760 - auc: 0.9370 - loss: 0.3073
# Epoch 00038: val_loss did not improve from 0.33406
# 32/32 [==============================] - 3s 104ms/step - accuracy: 0.8760 - auc: 0.9370 - loss: 0.3073 - val_accuracy: 0.8348 - val_auc: 0.9242 - val_loss: 0.3579 - lr: 3.9360e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 3.3488102400000014e-05.
# Epoch 39/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8359 - auc: 0.9080 - loss: 0.3735
# Epoch 00039: val_loss improved from 0.33406 to 0.32118, saving model to fold-5.h5
# 32/32 [==============================] - 6s 173ms/step - accuracy: 0.8359 - auc: 0.9080 - loss: 0.3735 - val_accuracy: 0.8393 - val_auc: 0.9395 - val_loss: 0.3212 - lr: 3.3488e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.8790481920000014e-05.
# Epoch 40/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8623 - auc: 0.9261 - loss: 0.3330
# Epoch 00040: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 108ms/step - accuracy: 0.8623 - auc: 0.9261 - loss: 0.3330 - val_accuracy: 0.8348 - val_auc: 0.9191 - val_loss: 0.3682 - lr: 2.8790e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.503238553600001e-05.
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8428 - auc: 0.9184 - loss: 0.3559
# Epoch 00041: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 108ms/step - accuracy: 0.8428 - auc: 0.9184 - loss: 0.3559 - val_accuracy: 0.8527 - val_auc: 0.9253 - val_loss: 0.3336 - lr: 2.5032e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.202590842880001e-05.
# Epoch 42/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8242 - auc: 0.9113 - loss: 0.3654
# Epoch 00042: val_loss did not improve from 0.32118
# 32/32 [==============================] - 4s 113ms/step - accuracy: 0.8242 - auc: 0.9113 - loss: 0.3654 - val_accuracy: 0.8438 - val_auc: 0.9262 - val_loss: 0.3356 - lr: 2.2026e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 1.9620726743040006e-05.
# Epoch 43/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8643 - auc: 0.9345 - loss: 0.3290
# Epoch 00043: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 106ms/step - accuracy: 0.8643 - auc: 0.9345 - loss: 0.3290 - val_accuracy: 0.8571 - val_auc: 0.9271 - val_loss: 0.3292 - lr: 1.9621e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 1.769658139443201e-05.
# Epoch 44/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8604 - auc: 0.9278 - loss: 0.3315
# Epoch 00044: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 107ms/step - accuracy: 0.8604 - auc: 0.9278 - loss: 0.3315 - val_accuracy: 0.8482 - val_auc: 0.9272 - val_loss: 0.3370 - lr: 1.7697e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 1.6157265115545607e-05.
# Epoch 45/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8613 - auc: 0.9291 - loss: 0.3309
# Epoch 00045: val_loss did not improve from 0.32118
# 32/32 [==============================] - 4s 113ms/step - accuracy: 0.8613 - auc: 0.9291 - loss: 0.3309 - val_accuracy: 0.8482 - val_auc: 0.9293 - val_loss: 0.3285 - lr: 1.6157e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.4925812092436487e-05.
# Epoch 46/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8398 - auc: 0.9232 - loss: 0.3410
# Epoch 00046: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 108ms/step - accuracy: 0.8398 - auc: 0.9232 - loss: 0.3410 - val_accuracy: 0.8571 - val_auc: 0.9283 - val_loss: 0.3296 - lr: 1.4926e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.3940649673949189e-05.
# Epoch 47/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8535 - auc: 0.9232 - loss: 0.3399
# Epoch 00047: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 107ms/step - accuracy: 0.8535 - auc: 0.9232 - loss: 0.3399 - val_accuracy: 0.8482 - val_auc: 0.9278 - val_loss: 0.3311 - lr: 1.3941e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3152519739159351e-05.
# Epoch 48/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8711 - auc: 0.9372 - loss: 0.3182
# Epoch 00048: val_loss did not improve from 0.32118
# 32/32 [==============================] - 4s 113ms/step - accuracy: 0.8711 - auc: 0.9372 - loss: 0.3182 - val_accuracy: 0.8438 - val_auc: 0.9292 - val_loss: 0.3307 - lr: 1.3153e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.252201579132748e-05.
# Epoch 49/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8652 - auc: 0.9354 - loss: 0.3167
# Epoch 00049: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 104ms/step - accuracy: 0.8652 - auc: 0.9354 - loss: 0.3167 - val_accuracy: 0.8571 - val_auc: 0.9302 - val_loss: 0.3264 - lr: 1.2522e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.2017612633061985e-05.
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - accuracy: 0.8340 - auc: 0.9154 - loss: 0.3605
# Epoch 00050: val_loss did not improve from 0.32118
# 32/32 [==============================] - 3s 106ms/step - accuracy: 0.8340 - auc: 0.9154 - loss: 0.3605 - val_accuracy: 0.8527 - val_auc: 0.9302 - val_loss: 0.3242 - lr: 1.2018e-05
#
# Time (sec) elapsed:  355.4
# ...
# ...

# %%
# lr_finder.plot_loss()

# %%
# lr_finder.plot_lr()

# %%
def plot_auc(hist):
    plt.figure(figsize=(14,6))
    
    plt.plot(hist.history['auc'], label='Training auc')
    plt.plot(hist.history['val_auc'], label='Validation auc')
    plt.title('AUC')
    plt.legend(loc='lower right')
    plt.ylabel('AUC')
    plt.xlabel('epoch')
    plt.grid()
    plt.show();

# %%
for fold in range(0, FOLDS):
    plot_auc(histories[fold])

# %%
def plot_loss(hist):
    plt.figure(figsize=(14,6))
    
    plt.plot(hist.history['loss'], label='Training loss')
    plt.plot(hist.history['val_loss'], label='Validation loss')
    plt.title('Loss')
    plt.legend(loc='lower right')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.grid()
    plt.show();

# %%
for fold in range(0, FOLDS):
    plot_loss(histories[fold])

# %%
# calcolo su test set. Su test set no augmentation

files_test = tf.io.gfile.glob(GCS_PATH + '/test*.tfrec')

num_total_test_files = len(files_test)

list_auc = []
list_acc = []

for fold in range(1, FOLDS + 1):
    
    model = build_model(dim=IMG_SIZES, ef=EFF_NETS)
    print('Evaluating on fold:', fold)
    
    model.load_weights('fold-%i.h5'%fold)
    
    test_loss, test_auc, test_acc = model.evaluate(get_test_dataset(files_test), verbose = 1, batch_size = BATCH_SIZE,
                                        steps = count_data_items(files_test)/BATCH_SIZE)

    print('Test AUC: ', round(test_auc, 3))
    print('Test ACC: ', round(test_acc, 3))
    print('')
    
    list_auc.append(test_auc)
    list_acc.append(test_acc)

# compute avg, std
np_auc = np.array(list_auc)
np_acc = np.array(list_acc)

avg_auc = np.mean(np_auc)
std_auc = np.std(np_auc)
avg_acc = np.mean(np_acc)
std_acc = np.std(np_acc)

print('AUC: %.3f , std: %.3f' %(avg_auc, std_auc))
print('ACC: %.3f , std: %.3f' %(avg_acc, std_acc))
# Out:
# Evaluating on fold: 1
# 42/42 [==============================] - 11s 253ms/step - loss: 0.2149 - auc: 0.9832 - accuracy: 0.9174
# Test AUC:  0.983
# Test ACC:  0.917
#
# Evaluating on fold: 2
# 42/42 [==============================] - 11s 255ms/step - loss: 0.1791 - auc: 0.9889 - accuracy: 0.9397
# Test AUC:  0.989
# Test ACC:  0.94
#
# Evaluating on fold: 3
# 42/42 [==============================] - 11s 261ms/step - loss: 0.1815 - auc: 0.9897 - accuracy: 0.9420
# Test AUC:  0.99
# Test ACC:  0.942
#
# Evaluating on fold: 4
# 42/42 [==============================] - 10s 249ms/step - loss: 0.1633 - auc: 0.9881 - accuracy: 0.9509
# Test AUC:  0.988
# Test ACC:  0.951
#
# Evaluating on fold: 5
# 42/42 [==============================] - 11s 259ms/step - loss: 0.1782 - auc: 0.9848 - accuracy: 0.9435
# Test AUC:  0.985
# Test ACC:  0.943
#
# AUC: 0.987 , std: 0.003
# ACC: 0.939 , std: 0.011

# %%
# all the label from the test dataset
y_true = np.concatenate([y for x, y in get_test_dataset(files_test)], axis=0)

# %%
avg_preds = np.zeros((count_data_items(files_test), 1))

for fold in range(1, FOLDS + 1):
    
    model = build_model(dim=IMG_SIZES, ef=EFF_NETS)
    print('Predicting  on fold:', fold)
    
    model.load_weights('fold-%i.h5'%fold)
    preds = model.predict(get_test_dataset(files_test), verbose = True,
                          steps = count_data_items(files_test)/BATCH_SIZE)
    
    avg_preds += preds * 1./FOLDS
# Out:
# Predicting  on fold: 1
# 42/42 [==============================] - 11s 260ms/step
# Predicting  on fold: 2
# 42/42 [==============================] - 10s 248ms/step
# Predicting  on fold: 3
# 42/42 [==============================] - 11s 252ms/step
# Predicting  on fold: 4
# 42/42 [==============================] - 10s 246ms/step
# Predicting  on fold: 5
# 42/42 [==============================] - 11s 255ms/step

# %%
# convert probabilities in labels
THRESHOLD = 0.50

y_pred = np.concatenate([y for y in avg_preds], axis=0)
y_pred = y_pred > THRESHOLD
y_pred = y_pred.astype(int)

acc = accuracy_score(y_true, y_pred)

print('The accuracy on TEST set is:', round(acc, 3))
# Out:
# The accuracy on TEST set is: 0.948

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

print('The Confusion Matrix')
print('TP:', tp)
print('TN:', tn)
print('FP:', fp)
print('FN:', fn)
# Out:
# The Confusion Matrix
# TP: 628
# TN: 646
# FP: 45
# FN: 25

# %%
SENS = tp/float(fn + tp)
SPEC = tn/float(tn + fp)

print('SENS:', round(SENS, 3))
print('SPEC:', round(SPEC, 3))
# Out:
# SENS: 0.962
# SPEC: 0.935

# %%
# check accuracy, FP, FN for different thresholds

THRESHOLDS = [0.5, 0.55, 0.6, 0.65, 0.7]

list_acc = []

for THRESHOLD in THRESHOLDS:
    y_pred = np.concatenate([y for y in avg_preds], axis=0)
    y_pred = y_pred > THRESHOLD
    y_pred = y_pred.astype(int)
    acc = accuracy_score(y_true, y_pred)

    print('THR: %f: accuracy on TEST set is: %.3f' %(THRESHOLD, round(acc, 3)))
    list_acc.append(acc)
    
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    print('FP:', fp)
    print('FN:', fn)
    SENS = tp/float(fn + tp)
    SPEC = tn/float(tn + fp)

    print('SENS:', round(SENS, 3))
    print('SPEC:', round(SPEC, 3))
# Out:
# THR: 0.500000: accuracy on TEST set is: 0.948
# FP: 45
# FN: 25
# SENS: 0.962
# SPEC: 0.935
# THR: 0.550000: accuracy on TEST set is: 0.956
# FP: 31
# FN: 28
# SENS: 0.957
# SPEC: 0.955
# THR: 0.600000: accuracy on TEST set is: 0.961
# FP: 22
# FN: 31
# SENS: 0.953
# SPEC: 0.968
# THR: 0.650000: accuracy on TEST set is: 0.959
# FP: 16
# FN: 39
# SENS: 0.94
# SPEC: 0.977
# THR: 0.700000: accuracy on TEST set is: 0.952
# FP: 12
# FN: 52
# SENS: 0.92
# SPEC: 0.983
